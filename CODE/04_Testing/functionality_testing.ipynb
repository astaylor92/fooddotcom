# %% [markdown]
# # Functionality Testing
#
# <hr style="border:2px solid black"> </hr>
#
# ## Perform misc analysis to support functionality testing
#
# Double-check statistics in visualizations using source data. Corresponds with functionality_testing.xlsx
#
# ---
#
# ### Import libraries

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import time

# %%
def num_uniques(ser):
    try:
        return len(ser.unique())
    except:
        return "Not unique check-able"
    
def summarize_df(df):
    print("======DATA SUMMARY======")
    print("{} rows by {} columns".format(df.shape[0], df.shape[1]))
    print("\n======COLUMNS======")
    print(df.dtypes)
    print("\n======PREVIEW======")
    display(df.head())
    print("\n======NUMERICAL COL SUMMARY======")
    print(df.describe())
    print("\n")
    for col in df.columns:
        print("{}: {} unique values".format(col, num_uniques(df[col])))

# %% [markdown]
# ---
# ### Test Ingredients Histogram

# %%
users_in = pd.read_csv('../05_RecipeExplorationTool/data/users_in_count2_mean4.csv')

# %%
summarize_df(users_in)
# Out:
# ======DATA SUMMARY======
# 599009 rows by 3 columns
#
# ======COLUMNS======
# user_id        int64
# recipe_id      int64
# ratings      float64
# dtype: object
#
# ======PREVIEW======
#    user_id  recipe_id  ratings
# 0        0       1118      5.0
# 1        0      27680      5.0
# 2        0      32541      5.0
# 3        0     137353      5.0
# 4        0      16428      5.0
# ======NUMERICAL COL SUMMARY======
#              user_id      recipe_id        ratings
# count  599009.000000  599009.000000  599009.000000
# mean     4450.979807   87765.758825       4.658464
# std      5644.504991   51419.630852       0.818773
# min         0.000000       0.000000       0.000000
# 25%       480.000000   43034.000000       5.000000
# 50%      1927.000000   87776.000000       5.000000
# 75%      6339.000000  132193.000000       5.000000
# max     25075.000000  178262.000000       5.000000
#
#
# user_id: 25006 unique values
# recipe_id: 85519 unique values
# ratings: 6 unique values

# %%
recipes_in = pd.read_parquet('../05_RecipeExplorationTool/data/recipes_in_count2_mean4.parquet').reset_index()

# %%
summarize_df(recipes_in)
# Out:
# ======DATA SUMMARY======
# 48454 rows by 7 columns
#
# ======COLUMNS======
# recipe_id       int64
# nutrition      object
# minutes         int64
# techniques     object
# cuisine        object
# meal_of_day    object
# ingredients    object
# dtype: object
#
# ======PREVIEW======
#    recipe_id                                          nutrition  minutes  \
# 0     137739  {'calories': 51.5, 'carbohydrates': 4.0, 'prot...       55
# 1     112140  {'calories': 269.8, 'carbohydrates': 5.0, 'pro...      130
# 2      59389  {'calories': 368.1, 'carbohydrates': 20.0, 'pr...       45
# 3      44061  {'calories': 352.9, 'carbohydrates': 28.0, 'pr...      190
# 4       5289  {'calories': 160.2, 'carbohydrates': 7.0, 'pro...        0
#
#                                           techniques         cuisine  \
# 0  {'Bake': 1, 'Barbecue': 0, 'Blanch': 0, 'Blend...  North American
# 1  {'Bake': 0, 'Barbecue': 0, 'Blanch': 0, 'Blend...   Uncategorized
# 2  {'Bake': 1, 'Barbecue': 0, 'Blanch': 0, 'Blend...   Uncategorized
# 3  {'Bake': 0, 'Barbecue': 0, 'Blanch': 0, 'Blend...  North American
# 4  {'Bake': 0, 'Barbecue': 0, 'Blanch': 0, 'Blend...  North American
#
#    meal_of_day                                        ingredients
# 0  Side Dishes  [winter squash, mexican seasoning, mixed spice...
# 1    Main Dish  [ground beef, yellow onions, diced tomatoes, t...
# 2  Side Dishes  [spreadable cheese with garlic and herbs, new ...
# 3      NO MEAL  [tomato juice, apple cider vinegar, sugar, sal...
# 4    Beverages  [milk, vanilla ice cream, frozen apple juice c...
# ======NUMERICAL COL SUMMARY======
#            recipe_id        minutes
# count   48454.000000   48454.000000
# mean    87532.195546     133.822244
# std     49778.583631    1966.124949
# min        40.000000       0.000000
# 25%     44397.500000      20.000000
# 50%     86717.000000      40.000000
# 75%    129724.500000      70.000000
# max    178262.000000  187200.000000
#
#
# recipe_id: 48454 unique values
# nutrition: Not unique check-able unique values
# minutes: 537 unique values
# techniques: Not unique check-able unique values
# cuisine: 40 unique values
# meal_of_day: 9 unique values
# ingredients: Not unique check-able unique values

# %%
user_recipe = users_in.merge(recipes_in, on='recipe_id')

# %%
summarize_df(user_recipe)
# Out:
# ======DATA SUMMARY======
# 339880 rows by 9 columns
#
# ======COLUMNS======
# user_id          int64
# recipe_id        int64
# ratings        float64
# nutrition       object
# minutes          int64
# techniques      object
# cuisine         object
# meal_of_day     object
# ingredients     object
# dtype: object
#
# ======PREVIEW======
#    user_id  recipe_id  ratings  \
# 0        0      27680      5.0
# 1      193      27680      5.0
# 2      197      27680      5.0
# 3      313      27680      5.0
# 4      330      27680      5.0
#
#                                            nutrition  minutes  \
# 0  {'calories': 414.7, 'carbohydrates': 35.0, 'pr...       15
# 1  {'calories': 414.7, 'carbohydrates': 35.0, 'pr...       15
# 2  {'calories': 414.7, 'carbohydrates': 35.0, 'pr...       15
# 3  {'calories': 414.7, 'carbohydrates': 35.0, 'pr...       15
# 4  {'calories': 414.7, 'carbohydrates': 35.0, 'pr...       15
#
#                                           techniques         cuisine  \
# 0  {'Bake': 0, 'Barbecue': 0, 'Blanch': 0, 'Blend...  North American
# 1  {'Bake': 0, 'Barbecue': 0, 'Blanch': 0, 'Blend...  North American
# 2  {'Bake': 0, 'Barbecue': 0, 'Blanch': 0, 'Blend...  North American
# 3  {'Bake': 0, 'Barbecue': 0, 'Blanch': 0, 'Blend...  North American
# 4  {'Bake': 0, 'Barbecue': 0, 'Blanch': 0, 'Blend...  North American
#
#   meal_of_day                                        ingredients
# 0   Beverages  [boiling water, tea bags, sugar, frozen limead...
# 1   Beverages  [boiling water, tea bags, sugar, frozen limead...
# 2   Beverages  [boiling water, tea bags, sugar, frozen limead...
# 3   Beverages  [boiling water, tea bags, sugar, frozen limead...
# 4   Beverages  [boiling water, tea bags, sugar, frozen limead...
# ======NUMERICAL COL SUMMARY======
#              user_id      recipe_id        ratings        minutes
# count  339880.000000  339880.000000  339880.000000  339880.000000
# mean     4487.143907   87035.399188       4.655946     155.247726
# std      5682.913685   49761.549422       0.823147    2147.284232
# min         0.000000      40.000000       0.000000       0.000000
# 25%       480.000000   44040.000000       5.000000      20.000000
# 50%      1927.000000   86331.500000       5.000000      40.000000
# 75%      6412.000000  129258.000000       5.000000      70.000000
# max     25074.000000  178262.000000       5.000000  187200.000000
#
#
# user_id: 23549 unique values
# recipe_id: 48454 unique values
# ratings: 6 unique values
# nutrition: Not unique check-able unique values
# minutes: 537 unique values
# techniques: Not unique check-able unique values
# cuisine: 40 unique values
# meal_of_day: 9 unique values
# ingredients: Not unique check-able unique values

# %% [markdown]
# ---
# ### Test ingredients histogram

# %%
user_recipe[['user_id', 'ingredients']].explode('ingredients') \
                                        .groupby('user_id', as_index=False).count() \
                                        .rename({'ingredients': 'num_ingredients'}, axis=1) \
                                        .groupby('num_ingredients', as_index=False).count() \
                                        .rename({'user_id': 'num_users'}, axis=1) \
                                        .head(20)
# Out:
#     num_ingredients  num_users
# 0                 2         40
# 1                 3        120
# 2                 4        222
# 3                 5        344
# 4                 6        411
# 5                 7        515
# 6                 8        492
# 7                 9        556
# 8                10        614
# 9                11        501
# 10               12        483
# 11               13        450
# 12               14        481
# 13               15        456
# 14               16        455
# 15               17        428
# 16               18        459
# 17               19        446
# 18               20        478
# 19               21        421

# %% [markdown]
# ---
# ### Test ingredients wordcloud

# %%
user_recipe_788 = user_recipe[user_recipe['user_id'] == 788]
user_recipe_788[['user_id', 'ingredients']].explode('ingredients') \
                                            .groupby(['user_id', 'ingredients'], as_index=False).size() \
                                            .sort_values('size', ascending=False).head(15)
# Out:
#     user_id       ingredients  size
# 55      788              salt     5
# 3       788      black pepper     3
# 24      788     garlic powder     3
# 42      788             onion     2
# 64      788      tomato sauce     2
# 21      788            garlic     2
# 45      788           paprika     2
# 19      788             flour     2
# 60      788             sugar     2
# 8       788    cayenne pepper     2
# 10      788      chili powder     2
# 54      788              rice     1
# 53      788  red kidney beans     1
# 52      788  prepared mustard     1
# 49      788      plain yogurt     1

# %% [markdown]
# ---
# ### Test techniques chart

# %%
user_recipe_788 = user_recipe[user_recipe['user_id'] == 788]
user_recipe_788['technique_l'] = user_recipe_788['techniques'].apply(lambda x: [k for k, v in x.items() if v > 0])
user_recipe_788[['user_id', 'technique_l']].explode('technique_l') \
                                            .groupby(['user_id', 'technique_l'], as_index=False).size() \
                                            .sort_values('size', ascending=False).head(15)
# Out:
# /Users/andrewtaylor/opt/anaconda3/envs/cse6242-project/lib/python3.6/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#     user_id  technique_l  size
# 0       788         Bake     4
# 7       788         Pour     4
# 2       788         Boil     3
# 3       788      Combine     3
# 6       788         Melt     2
# 10      788       Simmer     2
# 14      788         Toss     2
# 1       788        Blend     1
# 4       788        Drain     1
# 5       788        Grill     1
# 8       788  Refrigerate     1
# 9       788        Saute     1
# 11      788      Skillet     1
# 12      788        Steam     1
# 13      788       Strain     1

# %%
user_recipe['technique_l'] = user_recipe['techniques'].apply(lambda x: [k for k, v in x.items() if v > 0])
user_recipe[['user_id', 'technique_l']].explode('technique_l') \
                                            .groupby(['user_id', 'technique_l'], as_index=False).size() \
                                            .sort_values('size', ascending=False).head(15)
# Out:
#       user_id technique_l  size
# 2699       94        Bake   861
# 8692      275        Bake   827
# 2708       94     Combine   760
# 8701      275     Combine   746
# 6040      193        Bake   654
# 2729       94        Pour   621
# 6048      193     Combine   609
# 8721      275        Pour   606
# 6491      208        Bake   555
# 7491      241        Bake   555
# 5022      164        Bake   546
# 6499      208     Combine   515
# 3948      130        Bake   513
# 2703       94        Boil   495
# 8696      275        Boil   494

# %% [markdown]
# ---
# ### Test cuisine chart

# %%
user_recipe_788[['cuisine']].groupby('cuisine', as_index=False).size().sort_values('size', ascending=False)
# Out:
#           cuisine  size
# 1   Uncategorized     5
# 0  North American     4

# %%
user_recipe[['cuisine']].groupby('cuisine', as_index=False).size().sort_values('size', ascending=False)
# Out:
#                cuisine    size
# 39       Uncategorized  176500
# 27      North American   85002
# 7         Comfort Food   20603
# 10            European   18501
# 2                Asian   18230
# 35  South West Pacific    5200
# 14               Greek    3385
# 11              French    2125
# 13              German    2058
# 0              African    2045
# 31        Scandinavian    1266
# 18    Jewish Ashkenazi    1132
# 36             Spanish     934
# 34      South American     669
# 16           Hungarian     484
# 33       South African     324
# 9               Danish     251
# 38            Szechuan     202
# 4            Brazilian     178
# 22           Malaysian     136
# 6            Cantonese     112
# 19     Jewish Sephardi     100
# 25            Nepalese      91
# 29        Puerto Rican      56
# 21              Libyan      46
# 26            Nigerian      43
# 17               Iraqi      42
# 32                Soul      21
# 28         Palestinian      20
# 23           Mongolian      19
# 30       Saudi Arabian      18
# 15               Hunan      18
# 37            Sudanese      14
# 8            Congolese      12
# 3              Beijing      12
# 5            Cambodian      10
# 1              Angolan       9
# 12            Georgian       8
# 24            Namibian       2
# 20             Laotian       2
